# %%
mylist = [1,2,3,[4,5,['hello',True],23.6],34]

# %%
print(mylist[3][2][0])
# Out:
# hello

# %%
mylist[4]
# Out:
# 34

# %%
mylist.remove(34)

# %%
mylist
# Out:
# [1, 2, 3, [4, 5, ['hello', True], 23.6]]

# %%
mylist[3][2][0]
# Out:
# 'hello'

# %%
mydict = {'k1': [23,56, False], 'k2' : {'k3': [1, 'Hello']}}

# %%
print(mydict)
# Out:
# {'k1': [23, 56, False], 'k2': {'k3': [1, 'Hello']}}

# %%
mydict.keys()
# Out:
# dict_keys(['k1', 'k2'])

# %%
mydict['k2']['k3'][1]
# Out:
# 'Hello'
